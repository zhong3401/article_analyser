# %%
import pandas as pd

file_path = "2016_files_31_final.csv"

df = pd.read_csv(file_path)

display(df)
# Out:
#                                                 title  \
# 0      Hongrie: la banque centrale maintient ses taux
# 1          Turquie: croissance à 3,8% au 2e trimestre
# 2           La BCE laisse son taux directeur inchangé
# 3            Le RSA augmentera de 2% le 1er septembre
# 4      Brésil : hausse du salaire minimum à 207 euros
# 5    Prévision de croissance maintenue à 1,5% en 2016
# 6          Finlande: prix à la consommation en baisse
# 7   Eleveurs, Pôle Emploi, Smart : l'actu éco du jour
# 8     Zone euro : la croissance du privé au plus haut
# 9         La Finlande va sortir de la récession (FMI)
# 10        La BCE réexaminera sa politique en décembre
# 11  La Banque centrale américaine laisse ses taux ...
# 12           USA: la confiance du consommateur recule
# 13    Royal refuse les hausses de tarifs autoroutiers
# 14                      Brésil : les marchés inquiets
# 15               USA: baisse des prix à la production
# ...

# %%
display(df.iloc[:, -25:])
# Out:
#                            ci_0    cis_0           ei_0    eis_0  \
# 0                 not mentioned      NaN         stable      NaN
# 1                 not mentioned      NaN  not mentioned      NaN
# 2                 not mentioned      NaN         stable      NaN
# 3                 not mentioned      NaN  not mentioned      NaN
# 4                      too high   -0.500  not mentioned      NaN
# 5                      adequate    0.000         stable    0.000
# 6                           999  999.000            999  999.000
# 7                 not mentioned      NaN  not mentioned      NaN
# 8                 not mentioned      NaN  not mentioned      NaN
# 9                 not mentioned      NaN  not mentioned      NaN
# 10                not mentioned      NaN  not mentioned      NaN
# 11                not mentioned      NaN  not mentioned      NaN
# 12                     too high   -0.500  not mentioned      NaN
# ...

# %%
df.iloc[4]
# Out:
# title              Brésil : hausse du salaire minimum à 207 euros
# publisher                           Le Figaro Newsflash - Economy
# publish_date                                           2015/12/30
# edition                                                       NaN
# section                                          Flash; Flash Eco
# length                                                        155
# byline                                                        NaN
# body            La présidente de gauche du Brésil, Dilma Rouss...
# graphic                                                         0
# response_id                chatcmpl-7O3v2MeuZwMljQjjbwbiuJHgxqs4M
# ci_0                                                     too high
# cis_0                                                        -0.5
# ei_0                                                not mentioned
# eis_0                                                         NaN
# ...
